# %%
#Decision Tree Example using Scikit-learn
from sklearn.datasets import load_iris
from sklearn.tree import DecisionTreeClassifier, plot_tree
import matplotlib.pyplot as plt

#Load Dataset
iris = load_iris()
x, y = iris.data, iris.target

#Create and train the Decision Tree
clf = DecisionTreeClassifier(criterion="gini", max_depth=3, random_state=42)
clf.fit(x, y)

#predict sample data
sample = [[5.0, 3.6, 1.4, 0.2]]
prediction = clf.predict(sample)
print("predicted class:", iris.target_names[prediction[0]])

#visualize the tree
plt.figure(figsize=(12, 8))
plot_tree(clf, filled=True, feature_names=iris.feature_names, class_names=iris.target_names)
plt.show()
# Out:
# predicted class: setosa

# %%
import pandas as pd
import numpy as np
from sklearn.tree import DecisionTreeClassifier, plot_tree
import matplotlib.pyplot as plt

#Load Dataset
data = {
    'Age' : [25, 40, 35, 28, 50, 22],
    'Income' : [30000, 60000, 40000, 25000, 80000, 20000],
    'Student': [1, 0, 0, 1, 0, 1], #yas=1, no = 0
    'Loan_status': ['Approved', 'Approved', 'Denied', 'Approved', 'Approved', 'Denied']

    }
#creating dataset
df = pd.DataFrame(data)
#features(inputs: age,income,student) and targets(loan_status)
x = df[['Age','Income','Student']]
y = df['Loan_status']

#train the decision classifier
clf = DecisionTreeClassifier(criterion="entropy", max_depth=3, random_state=42)
clf.fit(x, y)

#predict for a new applicant
new_applicant_data = [[30, 45000, 1]] #age = 30, income = 45000, student=1
prediction = clf.predict(new_applicant_df)
print("Loan Decision:", prediction[0])
# Out:
# Loan Decision: Approved

# %%
#plot the decision tree
plt.figure(figsize=(10,6))
plot_tree(clf, filled= True, feature_names=['Age', 'Income', 'Student'], class_names=clf.classes_)
plt.show()
